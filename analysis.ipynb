# %%
import pandas as pd
from database.adatabase import ADatabase
import matplotlib.pyplot as plt

# %%
db = ADatabase("sapling")

# %%
db.connect()
kpi = db.retrieve("kpi")
db.disconnect()

# %%
db.cloud_connect()
db.drop("kpi")
db.store("kpi",kpi)
db.disconnect()

# %%
strategy_kpis = kpi.sort_values("return",ascending=False).groupby("strategy").first().reset_index().sort_values("return",ascending=False)
#strategy_kpis = kpi.sort_values("return",ascending=False).sort_values("return",ascending=False)

# %%
strategy_kpis
# Out:
#                   strategy  number_of_trades  standard_deviation  \
# 1          BOLLINGER_WIDTH              5040         307226.1740
# 9    STOCHASTIC_OSCILLATOR              5040         237454.0114
# 2  COEFFICIENT_OF_VARIANCE              5040         271848.0233
# 0                BOLLINGER              5040          89524.8978
# 4                     MACD              5040          42145.8267
# 5                      RSI              5040          19079.7304
# 8       STANDARD_DEVIATION              1008           7236.9249
# 6              RSI_TO_COEV             10080           2958.6533
# 7                     SKEW              5040           1836.8520
# 3                 KURTOSIS             10080            924.6256
#
#    coefficient_of_variance  sharpe        return  holding_period  positions  \
# 1                   1.6285  3.5593  1.093511e+06               5          5
# 9                   1.7035  4.4239  1.050465e+06               5          5
# 2                   1.6397  3.4231  9.305612e+05               5          5
# 0                   1.3603  3.5184  3.149868e+05               5          5
# 4                   1.4037  3.1241  1.316698e+05               5          5
# 5                   1.3831  3.7675  7.188208e+04               5          5
# 8                   1.2708  2.9300  2.120402e+04               5          1
# 6                   1.1101  3.4898  1.032512e+04               5         10
# 7                   0.8724  3.1229  5.736388e+03               5          5
# 3                   0.9392  3.0712  2.839708e+03               5         10
#
#    stop_loss  ascending  prices
# 1          1      False  prices
# 9          1      False  prices
# 2          1      False  prices
# 0          1      False  prices
# 4          1       True  prices
# 5          1       True  prices
# 8          1       True  prices
# 6          1       True  prices
# 7          1      False  prices
# 3          1      False  prices

# %%
plt.scatter(strategy_kpis["standard_deviation"].values,strategy_kpis["return"])
plt.show()
