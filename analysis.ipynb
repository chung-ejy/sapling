# %%
import pandas as pd
from database.adatabase import ADatabase
import matplotlib.pyplot as plt

# %%
db = ADatabase("sapling")

# %%
db.connect()
kpi = db.retrieve("kpi")
db.disconnect()

# %%
strategy_kpis = kpi.sort_values("return",ascending=False).groupby("strategy").first().reset_index().sort_values("return",ascending=False)

# %%
strategy_kpis
# Out:
#                   strategy  number_of_trades  standard_deviation  \
# 5                      RSI               510            209.1798
# 0                BOLLINGER               510            191.1166
# 1          BOLLINGER_WIDTH               510            172.3746
# 4                     MACD               510            141.6131
# 2  COEFFICIENT_OF_VARIANCE               510            134.4907
# 3                 KURTOSIS               510             40.9145
#
#    coefficient_of_variance  sharpe    return  holding_period  positions  \
# 5                   0.8923  2.8609  598.4322               5          5
# 0                   0.8549  2.9920  571.8158               5          5
# 1                   0.8301  3.0888  532.4361               5          5
# 4                   0.7717  2.9841  422.5866               5          5
# 2                   0.7722  2.9496  396.6949               5          5
# 3                   0.6448  3.3122  135.5187               5          5
#
#    stop_loss  ascending
# 5       0.05       True
# 0       0.05      False
# 1       0.05      False
# 4       0.05       True
# 2       0.05      False
# 3       0.05      False

# %%
plt.scatter(strategy_kpis["standard_deviation"].values,strategy_kpis["return"])
plt.show()
