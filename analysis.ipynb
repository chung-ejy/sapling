# %%
import pandas as pd
from database.adatabase import ADatabase
import matplotlib.pyplot as plt

# %%
db = ADatabase("sapling")

# %%
db.connect()
kpi = db.retrieve("kpi")
db.disconnect()

# %%
db.cloud_connect()
db.drop("kpi")
db.store("kpi",kpi)
db.disconnect()

# %%
strategy_kpis = kpi.sort_values("return",ascending=False).groupby("strategy").first().reset_index().sort_values("return",ascending=False)
# strategy_kpis = kpi.sort_values("return",ascending=False).sort_values("return",ascending=False)

# %%
strategy_kpis
# Out:
#                    strategy  number_of_trades  standard_deviation  \
# 2           BOLLINGER_WIDTH              1008        2.489735e+11
# 12    STOCHASTIC_OSCILLATOR              1008        2.351239e+11
# 0            AVERAGE_RETURN              1008        4.590291e+10
# 3   COEFFICIENT_OF_VARIANCE              1008        2.689432e+10
# 1                 BOLLINGER              1008        1.205326e+10
# 5                      MACD              1008        7.497519e+08
# 8                       RSI              1008        4.027539e+08
# 6            MOVING_AVERAGE              1008        4.299301e+07
# 11       STANDARD_DEVIATION              1008        8.065526e+04
# 9               RSI_TO_COEV              1008        2.669747e+04
# 4                  KURTOSIS              1008        1.837671e+04
# 13      TECH_FACTOR_LOADING               572        1.021360e+04
# 10                     SKEW              1008        7.879207e+03
# 7                    RANDOM              1008        5.660922e+03
#
#     coefficient_of_variance  sharpe        return  holding_period  positions  \
# 2                    3.0124  5.5168  1.373535e+12               5          1
# 12                   2.8454  4.8327  1.136288e+12               5          1
# 0                    2.4501  6.4263  2.949850e+11               5          1
# 3                    2.7372  5.2358  1.408142e+11               5          1
# 1                    2.8870  5.3708  6.473515e+10               5          1
# 5                    2.7947  5.3254  3.992697e+09               5          1
# 8                    2.7689  6.0691  2.444369e+09               5          1
# 6                    2.0585  4.2231  1.815623e+08               5          1
# 11                   1.4773  3.2396  2.612875e+05               5          1
# 9                    1.3104  3.7683  1.006046e+05               5          1
# 4                    1.3660  3.9540  7.266227e+04               5          1
# 13                   1.5726  3.6478  3.725707e+04               5          1
# 10                   0.9170  3.1838  2.508550e+04               5          1
# 7                    1.1419  3.4891  1.975156e+04               5          1
#
#     stop_loss  ascending  prices
# 2        0.05      False  prices
# 12       0.05      False  prices
# 0        0.05       True  prices
# 3        0.05      False  prices
# 1        0.05      False  prices
# 5        0.05       True  prices
# 8        0.05       True  prices
# 6        0.05       True  prices
# 11       0.05       True  prices
# 9        0.05       True  prices
# 4        0.05      False  prices
# 13       0.05       True  prices
# 10       0.05      False  prices
# 7        0.05      False  prices

# %%
plt.scatter(strategy_kpis["standard_deviation"].values,strategy_kpis["return"])
plt.show()
