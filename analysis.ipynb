# %%
import pandas as pd
from database.adatabase import ADatabase
import matplotlib.pyplot as plt

# %%
db = ADatabase("sapling")

# %%
db.connect()
kpi = db.retrieve("kpi")
db.disconnect()

# %%
strategy_kpis = kpi.sort_values("return",ascending=False).groupby("strategy").first().reset_index().sort_values("return",ascending=False)

# %%
strategy_kpis
# Out:
#                    strategy  number_of_trades  standard_deviation  \
# 3                  KURTOSIS               102             71.1994
# 9        STANDARD_DEVIATION               102             83.2023
# 13                 UNITY_AI                81             50.2038
# 6                       RSI               510             74.5959
# 10    STOCHASTIC_OSCILLATOR              1020             57.4421
# 5                    RANDOM               102             25.7060
# 1           BOLLINGER_WIDTH               102             53.9373
# 2   COEFFICIENT_OF_VARIANCE               102             53.9373
# 0                 BOLLINGER               102            123.6026
# 11             TECHNICAL_AI                81             27.8924
# 4                      MACD              1020             40.4493
# 8                      SKEW               102             40.8815
# 12                  TECH_AI               405             13.3670
# 7               RSI_TO_COEV               102             15.1504
#
#     coefficient_of_variance  sharpe    return  holding_period  positions  \
# 3                    0.7111  3.0169  214.8038               5          1
# 9                    1.7389  2.3140  192.5313               5          1
# 13                   0.7115  3.2527  163.2969               5          1
# 6                    0.7355  2.0407  152.2278               5          5
# 10                   0.7261  2.4035  138.0593               5         10
# 5                    0.2535  5.3668  137.9601               5          1
# 1                    1.5699  2.5077  135.2579               5          1
# 2                    1.5699  2.5077  135.2579               5          1
# 0                    0.7425  1.0505  129.8493               5          1
# 11                   0.7993  4.2103  117.4361               5          1
# 4                    0.6308  2.6706  108.0251               5         10
# 8                    0.6800  1.5942   65.1735               5          1
# 12                   0.5451  2.8870   38.5903               5          5
# 7                    0.6109  2.5163   38.1236               5          1
#
#     stop_loss  ascending
# 3           1      False
# 9           1       True
# 13          1       True
# 6           1       True
# 10          1      False
# 5           1       True
# 1           1       True
# 2           1       True
# 0           1      False
# 11          1      False
# 4           1       True
# 8           1       True
# 12          1      False
# 7           1      False

# %%
plt.scatter(strategy_kpis["standard_deviation"].values,strategy_kpis["return"])
plt.show()
