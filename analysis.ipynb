# %%
import pandas as pd
from database.adatabase import ADatabase
import matplotlib.pyplot as plt

# %%
db = ADatabase("sapling")

# %%
db.connect()
kpi = db.retrieve("kpi")
db.disconnect()

# %%
strategy_kpis = kpi.sort_values("return",ascending=False).groupby(["strategy"]).first().sort_values("return",ascending=False).reset_index()

# %%
strategy_kpis
# Out:
#                    strategy  number_of_trades  standard_deviation  \
# 0                       RSI               515            242.1295
# 1            AVERAGE_RETURN               515            221.6689
# 2   COEFFICIENT_OF_VARIANCE               515            159.8755
# 3                      MACD               515            128.2986
# 4            MOVING_AVERAGE               515            117.5013
# 5     STOCHASTIC_OSCILLATOR               515            132.1476
# 6                 TECHNICAL               405             92.1351
# 7           BOLLINGER_WIDTH               515             98.1988
# 8                 BOLLINGER               515             91.8626
# 9                   TECH_AI               405             75.0096
# 10      TECH_FACTOR_LOADING               405             59.8253
# 11       STANDARD_DEVIATION               515             39.5596
# 12                 KURTOSIS               515             42.6145
# 13                     SKEW               515             26.9200
# 14                   RANDOM               515             20.7733
#
#     coefficient_of_variance  sharpe    return  holding_period  positions  \
# 0                    0.9132  2.9921  724.4840               5          5
# 1                    0.9296  3.1964  708.5520               5          5
# 2                    0.8267  2.9075  464.8346               5          5
# 3                    0.6587  3.4657  444.6385               5          5
# 4                    0.9843  3.5346  415.3209               5          5
# 5                    0.9643  3.0795  406.9541               5          5
# 6                    0.5708  3.5792  329.7661               5          5
# 7                    0.9981  3.2703  321.1355               5          5
# 8                    0.8564  3.4240  314.5350               5          5
# 9                    0.6501  3.8951  292.1677               5          5
# 10                   0.7805  3.0208  180.7222               5          5
# 11                   0.9376  3.5500  140.4373               5          5
# 12                   0.6729  2.7888  118.8447               5          5
# 13                   0.6142  2.6131   70.3446               5          5
# 14                   0.6237  3.3032   68.6190               5          5
#
#     stop_loss  ascending
# 0        0.05       True
# 1        0.05       True
# 2        0.05      False
# 3        0.05       True
# 4        0.05       True
# 5        0.05      False
# 6        0.05       True
# 7        0.05      False
# 8        0.05      False
# 9        0.05      False
# 10       0.05      False
# 11       0.05       True
# 12       0.05      False
# 13       0.05      False
# 14       0.05       True

# %%
plt.scatter(strategy_kpis["standard_deviation"].values,strategy_kpis["return"])
plt.show()
