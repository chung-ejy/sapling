# %%
import pandas as pd
from database.adatabase import ADatabase
import matplotlib.pyplot as plt

# %%
db = ADatabase("sapling")

# %%
db.connect()
kpi = db.retrieve("kpi")
db.disconnect()

# %%
db.cloud_connect()
db.drop("kpi")
db.store("kpi",kpi)
db.disconnect()

# %%
strategy_kpis = kpi.sort_values("return",ascending=False).groupby("strategy").first().reset_index().sort_values("return",ascending=False)
#strategy_kpis = kpi.sort_values("return",ascending=False).sort_values("return",ascending=False)

# %%
strategy_kpis
# Out:
#                    strategy  number_of_trades  standard_deviation  \
# 0            AVERAGE_RETURN              1008        1.565519e+06
# 2           BOLLINGER_WIDTH              5040        3.072262e+05
# 12    STOCHASTIC_OSCILLATOR              5040        2.374540e+05
# 3   COEFFICIENT_OF_VARIANCE              5040        2.718480e+05
# 1                 BOLLINGER              5040        8.952490e+04
# 5                      MACD              5040        4.214583e+04
# 6            MOVING_AVERAGE              1008        2.557487e+04
# 8                       RSI              5040        1.907973e+04
# 11       STANDARD_DEVIATION              1008        7.236925e+03
# 9               RSI_TO_COEV             10080        2.958653e+03
# 10                     SKEW             10080        1.948133e+03
# 13      TECH_FACTOR_LOADING               572        1.244264e+03
# 4                  KURTOSIS             10080        9.246256e+02
# 7                    RANDOM             10080        7.182264e+02
#
#     coefficient_of_variance  sharpe        return  holding_period  positions  \
# 0                    1.6310  4.2899  6.715951e+06               5          1
# 2                    1.6285  3.5593  1.093511e+06               5          5
# 12                   1.7035  4.4239  1.050465e+06               5          5
# 3                    1.6397  3.4231  9.305612e+05               5          5
# 1                    1.3603  3.5184  3.149868e+05               5          5
# 5                    1.4037  3.1241  1.316698e+05               5          5
# 6                    1.3744  3.0701  7.851666e+04               5          1
# 8                    1.3831  3.7675  7.188208e+04               5          5
# 11                   1.2708  2.9300  2.120402e+04               5          1
# 9                    1.1101  3.4898  1.032512e+04               5         10
# 10                   0.9813  3.3897  6.603568e+03               5         10
# 13                   1.1461  3.3987  4.228874e+03               5          1
# 4                    0.9392  3.0712  2.839708e+03               5         10
# 7                    0.9996  3.2595  2.341023e+03               5         10
#
#     stop_loss  ascending  prices
# 0           1       True  prices
# 2           1      False  prices
# 12          1      False  prices
# 3           1      False  prices
# 1           1      False  prices
# 5           1       True  prices
# 6           1       True  prices
# 8           1       True  prices
# 11          1       True  prices
# 9           1       True  prices
# 10          1      False  prices
# 13          1       True  prices
# 4           1      False  prices
# 7           1      False  prices

# %%
plt.scatter(strategy_kpis["standard_deviation"].values,strategy_kpis["return"])
plt.show()
