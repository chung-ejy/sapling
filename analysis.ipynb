# %%
import pandas as pd
from database.adatabase import ADatabase
import matplotlib.pyplot as plt

# %%
db = ADatabase("sapling")

# %%
db.connect()
kpi = db.retrieve("kpi")
db.disconnect()

# %%
strategy_kpis = kpi.sort_values("return",ascending=False).groupby("strategy").first().reset_index().sort_values("return",ascending=False)

# %%
strategy_kpis
# Out:
#                    strategy  number_of_trades  standard_deviation  \
# 4                  KURTOSIS               103             62.8823
# 11       STANDARD_DEVIATION               103             71.9416
# 0            AVERAGE_RETURN               515             65.2141
# 12    STOCHASTIC_OSCILLATOR              1030             54.2735
# 8                       RSI               515             64.2866
# 2           BOLLINGER_WIDTH               103             48.7353
# 3   COEFFICIENT_OF_VARIANCE               103             48.7353
# 6            MOVING_AVERAGE               515             46.2608
# 15                 UNITY_AI                82             42.2233
# 1                 BOLLINGER               103            112.4775
# 7                    RANDOM               103             29.2913
# 5                      MACD              1030             38.4221
# 14                  TECH_AI                82             32.8974
# 13             TECHNICAL_AI               820             17.8956
# 10                     SKEW               103             36.0318
# 9               RSI_TO_COEV               103             15.7205
#
#     coefficient_of_variance  sharpe    return  holding_period  positions  \
# 4                    0.8363  2.8129  176.8811               5          1
# 11                   2.5565  2.1411  154.0320               5          1
# 0                    0.9006  1.9679  128.3329               5          5
# 12                   0.8111  2.2673  123.0518               5         10
# 8                    0.9041  1.7981  115.5939               5          5
# 2                    2.3741  2.3037  112.2698               5          1
# 3                    2.3741  2.3037  112.2698               5          1
# 6                    1.1603  2.3604  109.1962               5          5
# 15                   0.7352  2.5793  108.9083               5          1
# 1                    0.8117  0.9548  107.3897               5          1
# 7                    0.6645  3.5445  103.8233               5          1
# 5                    0.7248  2.4702   94.9111               5         10
# 14                   0.7470  2.7154   89.3295               5          1
# 13                   0.4972  3.3133   59.2925               5         10
# 10                   0.8990  1.2484   44.9833               5          1
# 9                    1.0102  1.8699   29.3962               5          1
#
#     stop_loss  ascending
# 4           1      False
# 11          1       True
# 0           1       True
# 12          1      False
# 8           1       True
# 2           1       True
# 3           1       True
# 6           1       True
# 15          1      False
# 1           1      False
# 7           1       True
# 5           1       True
# 14          1      False
# 13          1       True
# 10          1       True
# 9           1      False

# %%
plt.scatter(strategy_kpis["standard_deviation"].values,strategy_kpis["return"])
plt.show()
