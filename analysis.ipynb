# %%
import pandas as pd
from database.adatabase import ADatabase
import matplotlib.pyplot as plt

# %%
db = ADatabase("sapling")

# %%
db.connect()
kpi = db.retrieve("kpi")
db.disconnect()

# %%
strategy_kpis = kpi.sort_values("return",ascending=False).groupby(["strategy"]).first().sort_values("return",ascending=False).reset_index()

# %%
strategy_kpis
# Out:
#                   strategy  number_of_trades  standard_deviation  \
# 0    STOCHASTIC_OSCILLATOR               520            318.7233
# 1                      RSI               520            264.1645
# 2                BOLLINGER               520            277.1389
# 3  COEFFICIENT_OF_VARIANCE               520            230.0475
# 4                     MACD               520            207.7345
#
#    coefficient_of_variance  sharpe    return  holding_period  positions  \
# 0                   0.9389  3.0039  957.4090               5          5
# 1                   0.9018  3.1913  843.0273               5          5
# 2                   0.8969  3.0225  837.6532               5          5
# 3                   0.8675  3.0079  691.9580               5          5
# 4                   0.8008  3.0077  624.8015               5          5
#
#    stop_loss  ascending
# 0       0.05      False
# 1       0.05       True
# 2       0.05      False
# 3       0.05      False
# 4       0.05       True

# %%
plt.scatter(strategy_kpis["standard_deviation"].values,strategy_kpis["return"])
plt.show()
