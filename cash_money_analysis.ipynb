# %%
from backtest_functions.backtest_functions import BacktestFunctions as bf
from strategy.strategy import Strategy
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
from database.adatabase import ADatabase

# %%
db = ADatabase("sapling")

# %%
db.connect()
a = db.retrieve("kpi")
db.disconnect()
a.sort_values("return",ascending=False)
# Out:
#      number_of_trades  standard_deviation  coefficient_of_variance   sharpe  \
# 255              8100             59.2473                   1.5762   2.6403
# 264              8100             59.2473                   1.5762   2.6403
# 237              8100             59.2473                   1.5762   2.6403
# 246              8100             59.2473                   1.5762   2.6403
# 240              8100             44.8892                   0.8829   3.1583
# ..                ...                 ...                      ...      ...
# 71              10304             43.9618                  -1.3560 -10.2461
# 224              8200             81.0721                   9.7300  -8.4452
# 233              8200             81.0721                   9.7300  -8.4452
# 230              8200             89.2369                  -2.5535  -8.4156
# 221              8200             89.2369                  -2.5535  -8.4156
#
#        return             strategy  holding_period  positions  stop_loss  \
# 255  156.4285            TECHNICAL               5         10       0.05
# 264  156.4285            TECHNICAL               5         10       0.05
# 237  156.4285              TECH_AI               5         10       0.05
# 246  156.4285              TECH_AI               5         10       0.05
# 240  141.7719              TECH_AI               5         20       0.05
# ..        ...                  ...             ...        ...        ...
# 71  -450.4356             KURTOSIS               5         20       1.00
# 224 -684.6727  TECH_FACTOR_LOADING               5         20       1.00
# 233 -684.6727  TECH_FACTOR_LOADING               5         20       1.00
# 230 -750.9837  TECH_FACTOR_LOADING               5         10       1.00
# 221 -750.9837  TECH_FACTOR_LOADING               5         10       1.00
#
#      ascending
# 255       True
# 264      False
# 237       True
# 246      False
# 240       True
# ..         ...
# 71       False
# 224       True
# 233      False
# 230      False
# 221       True
#
# [270 rows x 10 columns]

# %%
db.cloud_connect()
db.store("kpi",a)
db.disconnect()
